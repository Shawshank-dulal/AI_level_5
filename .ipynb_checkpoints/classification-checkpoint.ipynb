# %%
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %% [markdown]
# #### Here I have imported fetch_openml in order to do a fetch of mnist_784 dataset

# %%
mnist=fetch_openml("mnist_784",version=1) # Fetching dataset

# %%
x,y=np.array(mnist.data),mnist.target

# %% [markdown]
# #### Since our dataset comprises of categorical data mainly data, target, class, feature_names and so on and we only need the dataset and the target set, we have selected those only.

# %%
plt.figure()
plt.imshow(x[0].reshape(28,28),cmap=mpl.cm.binary,interpolation="nearest")
plt.show()
print("And the result for the above image is",y[0])
# Out:
# And the result for the above image is 5

# %%
print(type(y[0]))
# Out:
# <class 'str'>

# %%
y=y.astype(np.uint8) # Since our target is of data type "str", it is being cast to "int"

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,stratify=y)

# %% [markdown]
# #### The splitting of dataset is required to make sure that the model gets sufficient new data in order to test if the model was tuned correctly or not.

# %%
model=LogisticRegression(C=1.0,solver="saga",n_jobs=4,max_iter=1000,
                         tol=0.001,intercept_scaling=1,random_state=42,verbose=0,
                         warm_start=False,class_weight=None)
model.fit(x_train,y_train)
predicted=model.predict(x_test)

# %% [markdown]
# #### C is set to default. since our dataset is normally large, and saga is comparitively faster than sag so we have chosen saga as our solver. I have defined 2 cores to be used for computation. Tolerance is set to 0.001. In order to produce same output in every runs, random state of 42 is set.

# %%
train_score=model.score(x_train,y_train)
test_score=model.score(x_test,y_test)
print("The accuracy of our classifier on the train set is",train_score,
      "And the accuracy of our classifier on the test set is",test_score)
# Out:
# The accuracy of our classifier on the train set is 0.9319387755102041 And the accuracy of our classifier on the test set is 0.9221904761904762

# %%
from sklearn.metrics import * # Importing the modules required for confusion matrix and classification report

# %%
fig,ax = plt.subplots(figsize=(20, 8))
plot_confusion_matrix(model,x_train,y_train, cmap=plt.cm.Blues, ax=ax)
plt.show()

# %% [markdown]
# #### As we can see from the confusion matrix above, out of 4832 data for the digit 1, only 4702 were predicted as 1, 12 were predicted as 2, another 12 were predicted to be 3, another 6 were predicted as 4 and so on. The true positives (correctly predicted ones) are the diagonal elements with blue color. The False Negatives for any digit is the row-wise sum of the predictions for that row excluding the True Positive value for that digit (i.e. blue colored one).  The False Positives for any class is the column-wise sum for that class excluding the True Positive one. And the True Negative for any digit is the sum of all rows and columns of the confusion matrix excluding the column and row of that digit.
#
# #### Now using the True Positive, True Negative, False Positive and False Negative values calculated with the help of above confusion matrix, we can analyze the overall performance of the classifier.  But in this notebook, I have used already available sklearn.metrics.classification_report to calculate the precision, recall and f1-score for the model below.

# %%
train_prediction=model.predict(x_train)
cr=classification_report(y_train,train_prediction)
print(cr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e0ebf52d06af> in <module>
# ----> 1 train_prediction=model.predict(x_train)
#       2 cr=classification_report(y_train,train_prediction)
#       3 print(cr)
#
# NameError: name 'model' is not defined

# %% [markdown]
# #### In the table above, we can have a look at the  precision, recall,f1-score and support for every digits from 0 to 10.  As we can deduce from the table above, the precision for the above classification is higher than 89% and since our dataset is distributed equally, the macro average and the weighted average is the same for precision, recall, f1 score and support. The precision for 1 is "0.96" which means that when it predicted 1, it is correct 96% of the time. Similarly,the recall for digit 2 is 0.98 which means that when the model predicted 2, if predicted correctly 98% of the time. The f1 score is the weighted average of the precision and recall of the consecutive digits
